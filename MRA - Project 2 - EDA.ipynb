# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Ananth'

# %%
os.chdir('C:/Users/Ananth/Downloads/Marketing & Retail Analytics/Week 2/Project - 2')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ananth\\Downloads\\Marketing & Retail Analytics\\Week 2\\Project - 2'

# %%
df = pd.read_csv('dataset_group.csv')

# %%
df.head()
# Out:
#          Date  Order_id        Product
# 0  2018-01-01         1         yogurt
# 1  2018-01-01         1           pork
# 2  2018-01-01         1  sandwich bags
# 3  2018-01-01         1     lunch meat
# 4  2018-01-01         1   all- purpose

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  object
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 483.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20641 entries, 0 to 20640
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      20641 non-null  datetime64[ns]
#  1   Order_id  20641 non-null  int64
#  2   Product   20641 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 483.9+ KB

# %%
df.describe()
# Out:
#            Order_id
# count  20641.000000
# mean     575.986289
# std      328.557078
# min        1.000000
# 25%      292.000000
# 50%      581.000000
# 75%      862.000000
# max     1139.000000

# %%
for column in df.columns:
     print("\n" + column)
     print(df[column].value_counts())
# Out:
# Date
# 2019-02-08    183
# 2019-02-20    146
# 2018-03-06    134
# 2018-03-01    127
# 2018-05-17    123
#              ...
# 2020-01-16      5
# 2018-09-24      4
# 2019-03-11      4
# 2019-09-05      4
# 2020-02-26      3
# Name: Date, Length: 603, dtype: int64
#
# Order_id
# 1013    34
# 226     34
# 1071    34
# 957     34
# 1105    33
#         ..
# 213      4
# 707      4
# 70       4
# 1139     3
# 408      3
# Name: Order_id, Length: 1139, dtype: int64
#
# Product
# poultry                         640
# soda                            597
# cereals                         591
# ice cream                       579
# cheeses                         578
# waffles                         575
# soap                            574
# lunch meat                      573
# bagels                          573
# eggs                            570
# juice                           570
# toilet paper                    569
# dinner rolls                    567
# ...

# %%
df.shape
# Out:
# (20641, 3)

# %%
df.isnull().sum()
# Out:
# Date        0
# Order_id    0
# Product     0
# dtype: int64

# %%
sns.distplot(df['Order_id']);

# %%
sns.pointplot(x = 'Date', y = 'Order_id', data = df)
plt.show()

# %% [markdown]
# ### Boxplot:

# %%
sns.boxplot(df['Order_id'])

# %%
sns.catplot(x="Product", y="Order_id", data=df)

# %%
sns.catplot(x="Product", y="Order_id", kind="bar", data=df)
